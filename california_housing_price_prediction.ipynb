# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score

df = pd.read_csv("housing.csv")

# %%
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
df.isna().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %%
df["total_bedrooms"]=df["total_bedrooms"].fillna(df["total_bedrooms"].mean())
df.isna().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# ocean_proximity       0
# dtype: int64

# %%
df.dtypes
# Out:
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# ocean_proximity        object
# dtype: object

# %%
x = df.drop("median_house_value",axis=1)
y = df["median_house_value"]
onehot=OneHotEncoder()
trans=ColumnTransformer([("onehot",onehot,["ocean_proximity"])],remainder="passthrough")
trans_x=pd.DataFrame(trans.fit_transform(x))

# %%
x.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income
# count    20640.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        419.266592   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
trans_x.describe()
# Out:
#                  0             1             2             3             4   \
# count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# mean       0.442636      0.317393      0.000242      0.110950      0.128779
# std        0.496710      0.465473      0.015563      0.314077      0.334963
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000000
# 50%        0.000000      0.000000      0.000000      0.000000      0.000000
# 75%        1.000000      1.000000      0.000000      0.000000      0.000000
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#                  5             6             7             8             9   \
# count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# mean    -119.569704     35.631861     28.639486   2635.763081    537.870553
# ...

# %%
#np.random.seed(108)
model = RandomForestRegressor()
x_train, x_test , y_train, y_test = train_test_split(trans_x,y,test_size=0.25)
model.fit(x_train,y_train)
y_preds = model.predict(x_test)

# %%
compdf = pd.DataFrame(y_test)
compdf["Predicted"] = y_preds
compdf
# Out:
#        median_house_value  Predicted
# 7322             164400.0  157710.00
# 15333             91200.0  216666.00
# 10397            184400.0  225164.03
# 2538              60000.0   97173.00
# 19060            254700.0  127981.00
# ...                   ...        ...
# 13095             52500.0   95970.00
# 10486            231400.0  244126.01
# 12292             68300.0   87062.00
# 5122             140400.0  149111.00
# 3572             483500.0  480752.77
#
# [5160 rows x 2 columns]

# %%
print(f"R2 score : {model.score(x_train,y_train)}")
# Out:
# R2 score : 0.9747244091326916

# %%
print(f"R2 score : {model.score(x_test,y_test)}")
# Out:
# R2 score : 0.8157586241337684

# %%
# %%time

print(cross_val_score(model,trans_x,y,cv=4))
# Out:
# [0.41266563 0.67053738 0.54511204 0.58988472]
# CPU times: total: 1min 23s
# Wall time: 1min 29s

# %%
print(f"Mean cross-validation score at cv=4 : {cross_val_score(model,trans_x,y,cv=4).mean()}")
# Out:
# Mean cross-validation score at cv=4 : 0.5508920095120362
